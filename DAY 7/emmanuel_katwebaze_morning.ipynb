# %%
# DAY 7: Python for Datascience

# %%
"""
1. Numpy - numerical computation in python
2. Pandas - data cleaning, transformation, merging, filtering

Data Visualization
Plotting - use library called matplotlib or seaborn - create - line, scatter, 
bar, histogram, heatmaps

Key concepts in Data Science:
1. Data - (text, images, videos) or semi structuured data (JSON, XML)
2. Data mining
3. Machine Learning
4. Statistical Analysis
5. Data Visualization
6. Big Data
7. Predictive Analysis

# Understanding Data Science workflow
_summary_
1. Problem definition
2. Data Acquisition - data.gov, kaggle, databases, APIs, External datasets
Ensure data quality, data validation, cleaning and processing, 
EDA - Exploratory Data Analysis

# Data Preparation and Preprocessing
- Missing data
- Wrong Format
- Null Values
- Duplicates
"""
# Out:
# '\n1. Numpy - numerical computation in python\n2. Pandas - data cleaning, transformation, merging, filtering\n\nData Visualization\nPlotting - use library called matplotlib or seaborn - create - line, scatter, \nbar, histogram, heatmaps\n\nKey concepts in Data Science:\n1. Data - (text, images, videos) or semi structuured data (JSON, XML)\n2. Data mining\n3. Machine Learning\n4. Statistical Analysis\n5. Data Visualization\n6. Big Data\n7. Predictive Analysis\n\n# Understanding Data Science workflow\n_summary_\n1. Problem definition\n2. Data Acquisition - data.gov, kaggle, databases, APIs, External datasets\nEnsure data quality, data validation, cleaning and processing, \nEDA - Exploratory Data Analysis\n\n# Data Preparation and Preprocessing\n- Missing data\n- Wrong Format\n- Null Values\n- Duplicates\n'

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
#Control Display of seaborn data
pd.options.display.max_columns=50
sns.set(style="darkgrid", rc={"axes.facecolor":"#CAF1DE"})

# %%
# loading dataset 
df = pd.read_csv('bse_dataset.csv')
df
# Out:
#               Timestamp What is your gender?  Age What is your emotion?  \
# 0   05/07/2023 09:38:39                 Male   21               Content
# 1   05/07/2023 09:38:57        Marabou stock   45                 Weird
# 2   05/07/2023 09:39:09              Female    20                 Happy
# 3   05/07/2023 09:39:12                 Male   21                 Happy
# 4   05/07/2023 09:39:14               Female   21                 Happy
# ..                  ...                  ...  ...                   ...
# 92  05/07/2023 09:53:56              Female    68                   Sad
# 93  05/07/2023 09:54:13                 Male   29               Hopeful
# 94  05/07/2023 09:54:28                 Male   22      Fighting poverty
# 95  05/07/2023 09:54:36                 Male   23          good and bad
# 96  05/07/2023 09:54:52                 male   30                hunger
#
#    Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
# Data Analysis Workflow
# Understanding of dataset Preparation
# Data cleaning - Data cleaning, wrong data, wrong format, 
# null values, duplicates
# Insight Data Visulization

# %%
# Understanding of data structure
# Checking shape of data
df.shape
# Out:
# (97, 11)

# %%
df.columns
# Out:
# Index(['Timestamp', 'What is your gender?', 'Age', 'What is your emotion?',
#        'Year of birth', 'What is your CGPA?',
#        'Do you have a Girl Friend or BOY Friend', 'Do you have Depression?',
#        'Do you have Anxiety?', 'Do you have Panic attack?',
#        'Did you have seek any specialist for a treatment? '],
#       dtype='object')

# %%
# Check for basic information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97 entries, 0 to 96
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           97 non-null     object
#  1   What is your gender?                                97 non-null     object
#  2   Age                                                 97 non-null     int64
#  3   What is your emotion?                               96 non-null     object
#  4   Year of birth                                       97 non-null     object
#  5   What is your CGPA?                                  97 non-null     object
#  6   Do you have a Girl Friend or BOY Friend             97 non-null     object
#  7   Do you have Depression?                             97 non-null     object
# ...

# %%
# Check null values
df.isnull().sum().sort_values(ascending=False)
# Out:
# What is your emotion?                                 1
# Timestamp                                             0
# What is your gender?                                  0
# Age                                                   0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
df2 = pd.read_csv('bse_dataset2.csv')
df2
# Out:
#                Timestamp What is your gender?   Age What is your emotion?  \
# 0    05/07/2023 09:38:39                 Male  21.0               Content
# 1    05/07/2023 09:38:57        Marabou stock  45.0                 Weird
# 2    05/07/2023 09:39:09              Female   20.0                 Happy
# 3    05/07/2023 09:39:12                 Male  21.0                 Happy
# 4    05/07/2023 09:39:14               Female  21.0                 Happy
# ..                   ...                  ...   ...                   ...
# 97   05/07/2023 09:56:37               Female  29.0             Grateful
# 98   05/07/2023 09:59:18              Female   21.0             Grateful
# 99   05/07/2023 10:11:02                 Male  21.0                   Yes
# 100  05/07/2023 10:17:36              Female   21.0                   Sad
# 101  05/07/2023 10:47:51                 Male  21.0                   Sad
#
#     Year of birth What is your CGPA? Do you have a Girl Friend or BOY Friend  \
# ...

# %%
df2.isnull().sum().sort_values(ascending=False)
# Out:
# Age                                                   2
# What is your emotion?                                 1
# Timestamp                                             0
# What is your gender?                                  0
# Year of birth                                         0
# What is your CGPA?                                    0
# Do you have a Girl Friend or BOY Friend               0
# Do you have Depression?                               0
# Do you have Anxiety?                                  0
# Do you have Panic attack?                             0
# Did you have seek any specialist for a treatment?     0
# dtype: int64

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102 entries, 0 to 101
# Data columns (total 11 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Timestamp                                           102 non-null    object
#  1   What is your gender?                                102 non-null    object
#  2   Age                                                 100 non-null    float64
#  3   What is your emotion?                               101 non-null    object
#  4   Year of birth                                       102 non-null    object
#  5   What is your CGPA?                                  102 non-null    object
#  6   Do you have a Girl Friend or BOY Friend             102 non-null    object
#  7   Do you have Depression?                             102 non-null    object
# ...

# %%
# check datatype
df2.dtypes
# Out:
# Timestamp                                              object
# What is your gender?                                   object
# Age                                                   float64
# What is your emotion?                                  object
# Year of birth                                          object
# What is your CGPA?                                     object
# Do you have a Girl Friend or BOY Friend                object
# Do you have Depression?                                object
# Do you have Anxiety?                                   object
# Do you have Panic attack?                              object
# Did you have seek any specialist for a treatment?      object
# dtype: object

# %%
# check null values in percentage
for i in df2.columns:
    if df2[i].isnull().any():
        print(i, "----------", df2[i].isnull().sum() * 100 / df2.shape[0], "%")
# Out:
# Age ---------- 1.9607843137254901 %
# What is your emotion? ---------- 0.9803921568627451 %

# %%
# Checking null values in figure
import missingno as msno
msno.bar(df2, color = "gray", fontsize=24)
# Out:
# <AxesSubplot:>

# %%
# checking for duplicates
df2.duplicated().sum()
# Out:
# 0

# %%
# Describe() statistical details about your data
# .T to the describe() method, you are transposing 
# the DataFrame, flipping the rows and columns.
df2.describe(include="object").T
# Out:
#                                                    count unique  \
# Timestamp                                            102     95
# What is your gender?                                 102     10
# What is your emotion?                                101     52
# Year of birth                                        102     19
# What is your CGPA?                                   102     63
# Do you have a Girl Friend or BOY Friend              102     14
# Do you have Depression?                              102     13
# Do you have Anxiety?                                 102     18
# Do you have Panic attack?                            102     13
# Did you have seek any specialist for a treatment?    102      9
#
#                                                                     top freq
# Timestamp                                           05/07/2023 09:40:10    2
# What is your gender?                                               Male   43
# ...

# %%
# Deals with integers
df2.describe().T
# Out:
#      count   mean       std   min   25%   50%    75%   max
# Age  100.0  22.95  6.213987  19.0  21.0  21.0  22.25  68.0

# %%
# Check for unique values
for i in df2.columns:
    print(i, "-----", df2[i].unique())
# Out:
# Timestamp ----- ['05/07/2023 09:38:39' '05/07/2023 09:38:57' '05/07/2023 09:39:09'
#  '05/07/2023 09:39:12' '05/07/2023 09:39:14' '05/07/2023 09:39:20'
#  '05/07/2023 09:39:21' '05/07/2023 09:39:23' '05/07/2023 09:39:26'
#  '05/07/2023 09:39:27' '05/07/2023 09:39:28' '05/07/2023 09:39:33'
#  '05/07/2023 09:39:38' '05/07/2023 09:39:40' '05/07/2023 09:39:45'
#  '05/07/2023 09:39:46' '05/07/2023 09:39:47' '05/07/2023 09:39:49'
#  '05/07/2023 09:39:50' '05/07/2023 09:39:54' '05/07/2023 09:39:56'
#  '05/07/2023 09:40:00' '05/07/2023 09:40:01' '05/07/2023 09:40:02'
#  '05/07/2023 09:40:08' '05/07/2023 09:40:10' '05/07/2023 09:40:12'
#  '05/07/2023 09:40:13' '05/07/2023 09:40:16' '05/07/2023 09:40:25'
#  '05/07/2023 09:40:26' '05/07/2023 09:40:27' '05/07/2023 09:40:33'
#  '05/07/2023 09:40:34' '05/07/2023 09:40:40' '05/07/2023 09:40:42'
#  '05/07/2023 09:40:46' '05/07/2023 09:40:47' '05/07/2023 09:40:54'
#  '05/07/2023 09:40:59' '05/07/2023 09:41:00' '05/07/2023 09:41:01'
# ...

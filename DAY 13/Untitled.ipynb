# %%
import pandas as pd
df = pd.read_csv('xeno_canto_records.csv')
df.head()
# Out:
#        id        gen          sp                   en  \
# 0  754598  Pyriglena     similis     Tapajos Fire-eye
# 1  695999  Pyriglena     similis     Tapajos Fire-eye
# 2  529078  Pyriglena       maura     Western Fire-eye
# 3  246018  Pyriglena       maura     Western Fire-eye
# 4  214239   Saltator  olivascens  Olivaceous Saltator
#
#                                  rec     cnt  \
# 0         JAYRSON ARAUJO DE OLIVEIRA  Brazil
# 1                     Felipe Arantes  Brazil
# 2  Benedito Pio da Silva Campos Neto  Brazil
# 3                       Jeremy Minns  Brazil
# 4                       Jeremy Minns  Brazil
#
#                                                 loc      lat      lng  alt  \
# 0                 Sinop, Cascalheiras - Mato Grosso -11.7519 -55.6380  340
# 1                            Vitória do Xingu, Pará  -3.3389 -51.8571  130
# 2  Chapada dos Guimarães, Mato Grosso. Cond. Manauá -15.4467 -55.7002  750
# ...
